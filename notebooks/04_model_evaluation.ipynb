# %% [markdown]
# # 04 — Model Evaluation

# %%
import joblib
from sklearn.metrics import classification_report, accuracy_score
model=joblib.load("../backend/models/cybersecurity_model.joblib")
prep=joblib.load("../backend/models/preprocessor.joblib")
le=joblib.load("../backend/models/label_encoder.joblib")
print("Model classes:",list(le.classes_))
print("Use the saved model with a held-out test set from notebook 03.")
